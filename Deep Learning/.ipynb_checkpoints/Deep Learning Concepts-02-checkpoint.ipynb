# %% [markdown]
# # ![image.png](attachment:image.png)
#
# <h2>Only Found the local minimum, global minimum is not found.</h2>
#
# <h3>Solution? Random start</h3>

# %% [markdown]
# # ![image.png](attachment:image.png)
#
# <h3> Increase the propability that we will get to the Global Minimum</h3>

# %% [markdown]
# # ![image.png](attachment:image.png)
#
# Another Solution is by using Momentum

# %% [markdown]
# # Sigmoid function may introduce a vanishing gradient problem because of it's nature
#
# ![image.png](attachment:image.png)
#
# <h3> Solution?  Replace the sigmoid function with other activation functions that are unlikely to produce a vanishing gradient such as TANH, or RELU.
